# %%
# !pip install ultralytics opencv-python numpy

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import os

# %%
# from google.colab import files
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# cd "/content/drive/MyDrive/UPenn_CIS5810_Project/FinalProject/IterationV1"

# %%
TARGET_PREF = 'auto' # auto, referee, teama, teamb
ENABLE_SAFE_MARGIN = False

# %%
MODEL_PATH = "../../models/v6/best.pt"  # fine-tuned weights
VIDEO_IN   = "../../videos/Q4_side_510-540.mp4"  # input video
VIDEO_OUT  = "../../results/demo_v1.mp4"         # output video

assert os.path.exists(MODEL_PATH), f"The weight does not exist. {MODEL_PATH}"
assert os.path.exists(VIDEO_IN),   f"The video does not exist. {VIDEO_IN}"

model = YOLO(MODEL_PATH)
names = (model.model.names if hasattr(model, "models") else model.names)
print("Classes:", names)

# 0 teamA, 1 teamB, 2 ball, 3 referee
PLAYER_IDS = {0, 1}
TEAM_A_ID  = 0
TEAM_B_ID  = 1
BALL_ID = 2
REFEREE_ID = 3
print(f"PLAYER_IDS={PLAYER_IDS}, BALL_ID={BALL_ID}, REFEREE_ID={REFEREE_ID}")

CONF_THRES = 0.20
IMGSZ = 1536
BASE_ZOOM = 1.40
MIN_ZOOM = 1.30
MAX_ZOOM = 3.5
CLOSEUP_PLAYER_FRAC = 0.3
CENTER_WEIGHT_PLAYER = 0.70
BALL_SAFE_PAD_X = 80
BALL_SAFE_PAD_Y = 80

HOLD_MAX_FRAMES = 40   # max frames to hold last ball-handler
prev_holder_id = None  # last ball-handler id
prev_center = None  # last camera center
prev_player_bb = None  # last selected bbox
no_ball_streak = 0     # consecutive no-ball counter
CAM_LIMIT_MARGIN_X = 400
CAM_LIMIT_MARGIN_Y = 900

cap = cv2.VideoCapture(VIDEO_IN)
assert cap.isOpened(), f"Cannot open the video{VIDEO_IN}"
fps = cap.get(cv2.CAP_PROP_FPS) or 30
W   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
H   = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(VIDEO_OUT, cv2.VideoWriter_fourcc(*"mp4v"), fps, (W, H))

print(f"Video: {W}x{H} @ {fps:.2f} fps")
# Out:
# Classes: {0: 'teamA', 1: 'teamB', 2: 'ball', 3: 'referee'}
# PLAYER_IDS={0, 1}, BALL_ID=2, REFEREE_ID=3
# Video: 3840x2160 @ 29.97 fps

# %%
def _center_of_box(bb):
    x1, y1, x2, y2 = bb
    return ((x1 + x2) / 2.0, (y1 + y2) / 2.0)

def choose_target_ball_nearest(tracks, debug=False):
    balls   = [(bb, cf) for (_, bb, cls, cf) in tracks if cls == BALL_ID]
    players = [(tid, bb) for (tid, bb, cls, _) in tracks if cls in PLAYER_IDS]

    if balls and players:
        ball_bb, _ = max(balls, key=lambda x: x[1])
        bcx, bcy   = _center_of_box(ball_bb)

        tid, pbb = min(
            players,
            key=lambda x: (
                (_center_of_box(x[1])[0] - bcx) ** 2 +
                (_center_of_box(x[1])[1] - bcy) ** 2
            )
        )
        pcx, pcy = _center_of_box(pbb)
        if debug:
            print(f"[choose] ball present -> nearest player tid={tid}, ball=({bcx:.1f},{bcy:.1f})")
        return np.array([pcx, pcy], dtype=float), tid, pbb, np.array([bcx, bcy], dtype=float)

    if players:
        p_centers = np.array([_center_of_box(bb) for (_, bb) in players], dtype=float)
        centroid  = p_centers.mean(axis=0)  # (cx_mean, cy_mean)

        def dist2_to_centroid(bb):
            cx, cy = _center_of_box(bb)
            return (cx - centroid[0]) ** 2 + (cy - centroid[1]) ** 2

        tid, pbb = min(players, key=lambda x: dist2_to_centroid(x[1]))
        pcx, pcy = _center_of_box(pbb)
        if debug:
            print(f"[choose] no ball -> centroid={tuple(np.round(centroid,1))}, pick tid={tid}")
        return np.array([pcx, pcy], dtype=float), tid, pbb, None

    if debug:
        print("[choose] no players -> return None")
    return None, None, None, None

def _ball_center_from_tracks(tracks):
    balls = [(bb, cf) for (_, bb, cls, cf) in tracks if cls == BALL_ID]
    if not balls:
        return None
    ball_bb, _ = max(balls, key=lambda x: x[1])
    return np.array(_center_of_box(ball_bb), dtype=float)

def _nearest_to_point(items_tid_bb, point_xy):
    """items_tid_bb: [(tid, bb), ...] ；point_xy: (x,y)"""
    tid, bb = min(
        items_tid_bb,
        key=lambda x: ( _center_of_box(x[1])[0]-point_xy[0] )**2 + ( _center_of_box(x[1])[1]-point_xy[1] )**2
    )
    return tid, bb

def _centroid_of_bboxes(items_tid_bb):
    if not items_tid_bb:
        return None
    centers = np.array([_center_of_box(bb) for (_, bb) in items_tid_bb], dtype=float)
    return centers.mean(axis=0)

def choose_target_by_pref(tracks, pref='auto', debug=False):
    pref = (pref or 'auto').lower()
    ball_center = _ball_center_from_tracks(tracks)

    if pref == 'referee':
        refs = [(tid, bb) for (tid, bb, cls, _) in tracks if cls == REFEREE_ID]
        if refs:
            if ball_center is not None:
                tid, bb = _nearest_to_point(refs, ball_center)
                cx, cy = _center_of_box(bb)
                if debug:
                    print(f"[pref=referee] nearest-to-ball ref tid={tid}")
                return np.array([cx, cy], dtype=float), tid, bb, ball_center
            else:
                centroid = _centroid_of_bboxes(refs)
                tid, bb = _nearest_to_point(refs, centroid)
                cx, cy = _center_of_box(bb)
                if debug:
                    print(f"[pref=referee] no ball -> centroid pick ref tid={tid}")
                return np.array([cx, cy], dtype=float), tid, bb, None
        if debug:
            print("[pref=referee] no referee -> fallback auto")
        return choose_target_ball_nearest(tracks, debug=debug)

    if pref in ('teama', 'teamb'):
        team_cls = 0 if pref == 'teama' else 1
        team_players = [(tid, bb) for (tid, bb, cls, _) in tracks if cls == team_cls]
        if team_players:
            centroid = _centroid_of_bboxes(team_players)
            tid, bb = _nearest_to_point(team_players, centroid)
            if debug:
                print(f"[pref={pref}] centroid center, zoom ref tid={tid}")
            return centroid.astype(float), tid, bb, ball_center
        if debug:
            print(f"[pref={pref}] no team players -> fallback auto")
        return choose_target_ball_nearest(tracks, debug=debug)

    return choose_target_ball_nearest(tracks, debug=debug)


def compute_zoom_target(player_bb, ball_center, center_xy, W, H,
                        closeup_frac=CLOSEUP_PLAYER_FRAC,
                        min_zoom=MIN_ZOOM, max_zoom=MAX_ZOOM,
                        pad_x=BALL_SAFE_PAD_X,
                        pad_y=BALL_SAFE_PAD_Y):
    if player_bb is None:
        return BASE_ZOOM

    x1, y1, x2, y2 = player_bb
    bbox_h = max(1.0, (y2 - y1))
    zoom_from_bbox = float(np.clip((closeup_frac * H) / bbox_h, min_zoom, max_zoom))

    if ball_center is not None and center_xy is not None:
        cx, cy = float(center_xy[0]), float(center_xy[1])
        dx = abs(ball_center[0] - cx)
        dy = abs(ball_center[1] - cy)

        need_w = 2*dx + 2*pad_x

        need_h = 2*dy + 2*pad_y

        zoom_bound_w = W / need_w if need_w > 0 else max_zoom
        zoom_bound_h = H / need_h if need_h > 0 else max_zoom
        zoom_from_bbox = min(zoom_from_bbox, zoom_bound_w, zoom_bound_h)

    return float(np.clip(zoom_from_bbox, min_zoom, max_zoom))

def crop_like_ptz(frame, center_xy, zoom,
                  limit_x=CAM_LIMIT_MARGIN_X,
                  limit_y=CAM_LIMIT_MARGIN_Y,
                  use_limit=ENABLE_SAFE_MARGIN):
    h, w = frame.shape[:2]
    zoom = max(1.0, float(zoom))

    view_w = int(w / zoom)
    view_h = int(h / zoom)

    cx, cy = float(center_xy[0]), float(center_xy[1])

    raw_x1 = cx - view_w / 2
    raw_y1 = cy - view_h / 2

    if use_limit:
        min_x = limit_x
        max_x = w - limit_x - view_w

        if max_x < min_x:
            valid_center_x = w / 2
            x1 = int(valid_center_x - view_w / 2)
        else:
            x1 = int(np.clip(raw_x1, min_x, max_x))

        min_y = limit_y
        max_y = h - limit_y - view_h

        if max_y < min_y:
            valid_center_y = h / 2
            y1 = int(valid_center_y - view_h / 2)
        else:
            y1 = int(np.clip(raw_y1, min_y, max_y))

    else:
        x1 = int(raw_x1)
        y1 = int(raw_y1)

    x1 = int(np.clip(x1, 0, w - view_w))
    y1 = int(np.clip(y1, 0, h - view_h))

    roi = frame[y1:y1+view_h, x1:x1+view_w]
    return cv2.resize(roi, (w, h))

def _find_bbox_by_id(tracks, tid):
    for (id_, bb, cls, _) in tracks:
        if id_ == tid:
            return bb
    return None

# %%
class SmoothPTZ:
    """
    center: 2D critically-damped spring + speed/acc limits
    zoom  : EMA
    """
    def __init__(self, W, H, fps,
                 k_center=10.0, # spring stiffness
                 zeta=0.90, # damping ratio
                 max_speed_px=1200.0, # pixels/sec
                 max_accel_px=4000.0, # pixels/sec^2
                 deadband_px=4.0, # deadband
                 zoom_tau_s=0.25, # time constant
                 zoom_min=1.0, zoom_max=3.5):
        self.W, self.H = W, H
        self.dt = 1.0 / max(1.0, float(fps))
        # center state
        self.c = np.array([W/2.0, H/2.0], dtype=float)  # position
        self.v = np.zeros(2, dtype=float) # velocity
        self.k = float(k_center)
        self.zeta = float(zeta)
        self.max_speed = float(max_speed_px)
        self.max_accel = float(max_accel_px)
        self.deadband = float(deadband_px)
        # zoom state
        self.z = 1.0
        self.zoom_min, self.zoom_max = float(zoom_min), float(zoom_max)
        # alpha = 1 - exp(-dt/tau)
        self.zoom_alpha = 1.0 - np.exp(-self.dt / float(zoom_tau_s))

    def step(self, target_center, target_zoom):
        # --- center: critically damped spring with clamps ---
        e = np.asarray(target_center, dtype=float) - self.c
        if np.hypot(e[0], e[1]) < self.deadband:
            e[:] = 0.0
        # a = k*e - 2*zeta*sqrt(k)*v
        a = self.k * e - 2.0 * self.zeta * np.sqrt(self.k) * self.v
        a_norm = np.hypot(a[0], a[1])
        if a_norm > self.max_accel:
            a *= (self.max_accel / a_norm)
        self.v += a * self.dt
        v_norm = np.hypot(self.v[0], self.v[1])
        if v_norm > self.max_speed:
            self.v *= (self.max_speed / v_norm)
        self.c += self.v * self.dt
        self.c[0] = float(np.clip(self.c[0], 0, self.W))
        self.c[1] = float(np.clip(self.c[1], 0, self.H))

        # --- zoom: EMA ---
        tz = float(np.clip(target_zoom, self.zoom_min, self.zoom_max))
        self.z += self.zoom_alpha * (tz - self.z)
        self.z = float(np.clip(self.z, self.zoom_min, self.zoom_max))

        return self.c.copy(), self.z

# %%
smoother = SmoothPTZ(
    W=W, H=H, fps=fps,
    k_center=10.0,
    zeta=0.90,
    max_speed_px=1200.0,
    max_accel_px=4000.0,
    deadband_px=4.0,
    zoom_tau_s=0.25,
    zoom_min=MIN_ZOOM, zoom_max=MAX_ZOOM
)

# %%
frame_idx = 0
while True:
    ok, frame = cap.read()
    if not ok:
        print("Video ended or read failed.")
        break

    # YOLO ByteTrack
    res = model.track(
        source=frame,
        conf=CONF_THRES,
        imgsz=IMGSZ,
        persist=True,
        verbose=False
    )[0]

    # tracks
    tracks = []
    boxes = res.boxes
    if boxes is not None and len(boxes) > 0:
        xyxy = boxes.xyxy.cpu().numpy()
        cls  = boxes.cls.cpu().numpy().astype(int)
        conf = boxes.conf.cpu().numpy()
        if boxes.id is not None:
            ids = boxes.id.cpu().numpy().astype(int)
        else:
            ids = np.arange(len(xyxy))
        for i in range(len(xyxy)):
            tracks.append((int(ids[i]), xyxy[i], int(cls[i]), float(conf[i])))

    uniq_cls = np.unique([c for (_,_,c,_) in tracks]) if tracks else []
    n_players = sum(1 for (_,_,c,_) in tracks if c in PLAYER_IDS)
    n_balls   = sum(1 for (_,_,c,_) in tracks if c == BALL_ID)

    player_center, chosen_id, player_bb, ball_center = choose_target_by_pref(
        tracks, pref=TARGET_PREF, debug=True
    )

    balls_present = (ball_center is not None)
    if balls_present:
        prev_holder_id = chosen_id
        prev_player_bb = player_bb
        no_ball_streak = 0
    else:
        no_ball_streak += 1
        held_bb = None
        if prev_holder_id is not None:
            held_bb = _find_bbox_by_id(tracks, prev_holder_id)
        if held_bb is not None:
            player_bb = held_bb
            cx, cy = _center_of_box(player_bb)
            player_center = np.array([cx, cy], dtype=float)
            chosen_id = prev_holder_id
        elif prev_center is not None and no_ball_streak <= HOLD_MAX_FRAMES:
            player_center = None  # prev_center
        else:
            pass

    if player_center is not None:
        if ball_center is not None:
            center_target = CENTER_WEIGHT_PLAYER * player_center + (1.0 - CENTER_WEIGHT_PLAYER) * ball_center
        else:
            center_target = player_center
    else:
        if (not balls_present) and (prev_center is not None) and (no_ball_streak <= HOLD_MAX_FRAMES):
            center_target = prev_center.copy()
        else:
            center_target = np.array([W/2.0, H/2.0], dtype=float)
            player_bb = None

    desired_zoom = compute_zoom_target(
        player_bb,
        ball_center if balls_present else None,
        center_target,
        W, H,
        closeup_frac=CLOSEUP_PLAYER_FRAC,
        min_zoom=MIN_ZOOM, max_zoom=MAX_ZOOM,
        pad_x=BALL_SAFE_PAD_X,
        pad_y=BALL_SAFE_PAD_Y
    )

    smooth_center, smooth_zoom = smoother.step(center_target, desired_zoom)

    if frame_idx < 5 or frame_idx % 10 == 0:
        pb_h = 0 if player_bb is None else (player_bb[3]-player_bb[1])
        pb_w = 0 if player_bb is None else (player_bb[2]-player_bb[0])
        print(
            f"[{frame_idx:04d}] uniq_cls={uniq_cls} players={n_players} balls={n_balls} "
            f"chosen_id={chosen_id} pb_size=({pb_w:.0f}x{pb_h:.0f}) "
            f"target=({center_target[0]:.1f},{center_target[1]:.1f}) "
            f"zoom_tgt={desired_zoom:.2f} "
            f"smooth=({smooth_center[0]:.1f},{smooth_center[1]:.1f}) "
            f"z={smooth_zoom:.2f}"
        )

    if boxes is not None and len(boxes) > 0:
        for i in range(len(boxes)):
            x1,y1,x2,y2 = map(int, boxes.xyxy[i].cpu().numpy())
            c = int(boxes.cls[i].cpu().numpy())
            if c == BALL_ID:
                cv2.rectangle(frame, (x1,y1), (x2,y2), (0,0,255), 2)
        if chosen_id is not None and boxes.id is not None:
            ids_arr = boxes.id.cpu().numpy().astype(int)
            for i, tid in enumerate(ids_arr):
                if tid == chosen_id:
                    x1,y1,x2,y2 = map(int, boxes.xyxy[i].cpu().numpy())
                    cv2.rectangle(frame, (x1,y1), (x2,y2), (0,255,0), 2)
                    break
        elif player_bb is not None:
            x1,y1,x2,y2 = map(int, player_bb)
            cv2.rectangle(frame, (x1,y1), (x2,y2), (0,255,0), 2)

    cv2.circle(frame, (int(smooth_center[0]), int(smooth_center[1])), 5, (0,255,255), -1)

    view = crop_like_ptz(
        frame,
        smooth_center,
        smooth_zoom,
        limit_x=CAM_LIMIT_MARGIN_X,
        limit_y=CAM_LIMIT_MARGIN_Y
    )
    out.write(view)
    prev_center = smooth_center.copy()
    prev_player_bb = player_bb
    frame_idx += 1

print("Done frames:", frame_idx)
cap.release()
out.release()
print("Saved:", os.path.abspath(VIDEO_OUT))
# Out:
# [choose] ball present -> nearest player tid=3, ball=(2502.4,1065.6)
# [0000] uniq_cls=[0 1 2 3] players=11 balls=1 chosen_id=3 pb_size=(68x148) target=(2521.2,1063.3) zoom_tgt=3.50 smooth=(1924.5,1079.9) z=1.31
# [choose] no ball -> centroid=(np.float64(1956.7), np.float64(1016.8)), pick tid=10
# [0001] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(56x148) target=(2529.2,1061.1) zoom_tgt=3.50 smooth=(1933.4,1079.6) z=1.59
# [choose] no ball -> centroid=(np.float64(1954.8), np.float64(1016.7)), pick tid=10
# [0002] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(56x149) target=(2527.3,1060.3) zoom_tgt=3.50 smooth=(1946.7,1079.2) z=1.82
# [choose] no ball -> centroid=(np.float64(1952.4), np.float64(1016.5)), pick tid=10
# [0003] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(63x148) target=(2522.7,1059.8) zoom_tgt=3.50 smooth=(1963.9,1078.6) z=2.03
# [choose] no ball -> centroid=(np.float64(1949.2), np.float64(1016.5)), pick tid=10
# [0004] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(82x147) target=(2513.0,1059.9) zoom_tgt=3.50 smooth=(1984.0,1078.0) z=2.22
# [choose] no ball -> centroid=(np.float64(1946.8), np.float64(1016.3)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1944.8), np.float64(1016.3)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1943.2), np.float64(1016.1)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1941.6), np.float64(1015.9)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1939.6), np.float64(1015.6)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1937.2), np.float64(1015.1)), pick tid=10
# [0010] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(79x140) target=(2493.0,1059.2) zoom_tgt=3.50 smooth=(2127.4,1073.2) z=2.92
# [choose] no ball -> centroid=(np.float64(1934.9), np.float64(1014.4)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1931.9), np.float64(1013.9)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1867.3), np.float64(1004.4)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1864.1), np.float64(1004.0)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1861.1), np.float64(1003.8)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1858.4), np.float64(1003.6)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1855.3), np.float64(1003.4)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1852.3), np.float64(1003.3)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1849.5), np.float64(1003.4)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1847.1), np.float64(1003.4)), pick tid=10
# [0020] uniq_cls=[0 1 3] players=12 balls=0 chosen_id=3 pb_size=(94x139) target=(2431.6,1057.8) zoom_tgt=3.50 smooth=(2313.7,1065.1) z=3.35
# [choose] no ball -> centroid=(np.float64(1845.0), np.float64(1003.3)), pick tid=10
# [choose] ball present -> nearest player tid=3, ball=(2389.2,1034.3)
# [choose] no ball -> centroid=(np.float64(1841.0), np.float64(1003.0)), pick tid=10
# [choose] ball present -> nearest player tid=3, ball=(2366.9,1032.8)
# [choose] ball present -> nearest player tid=3, ball=(2356.5,1032.9)
# [choose] ball present -> nearest player tid=3, ball=(2344.2,1033.9)
# [choose] ball present -> nearest player tid=3, ball=(2332.1,1036.8)
# [choose] ball present -> nearest player tid=3, ball=(2320.2,1040.6)
# [choose] ball present -> nearest player tid=3, ball=(2309.1,1046.5)
# [choose] ball present -> nearest player tid=3, ball=(2299.5,1055.3)
# [0030] uniq_cls=[0 1 2 3] players=12 balls=1 chosen_id=3 pb_size=(103x143) target=(2333.8,1052.7) zoom_tgt=3.50 smooth=(2378.8,1058.6) z=3.46
# [choose] ball present -> nearest player tid=3, ball=(2291.5,1064.3)
# [choose] ball present -> nearest player tid=3, ball=(2283.1,1075.6)
# [choose] ball present -> nearest player tid=3, ball=(2274.8,1087.9)
# [choose] ball present -> nearest player tid=3, ball=(2265.9,1100.9)
# [choose] ball present -> nearest player tid=8, ball=(2257.4,1114.9)
# [choose] no ball -> centroid=(np.float64(1806.8), np.float64(1001.8)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1804.2), np.float64(1001.8)), pick tid=10
# [choose] ball present -> nearest player tid=3, ball=(2247.5,1098.5)
# [choose] no ball -> centroid=(np.float64(1853.9), np.float64(1010.1)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1850.9), np.float64(1010.1)), pick tid=10
# [0040] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(70x139) target=(2282.4,1056.7) zoom_tgt=3.50 smooth=(2349.8,1067.8) z=3.49
# [choose] no ball -> centroid=(np.float64(1847.7), np.float64(1010.0)), pick tid=10
# [choose] ball present -> nearest player tid=3, ball=(2235.0,1070.9)
# [choose] no ball -> centroid=(np.float64(1841.0), np.float64(1010.1)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1838.2), np.float64(1010.0)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1835.3), np.float64(1009.8)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1832.6), np.float64(1010.1)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1878.3), np.float64(1020.4)), pick tid=4
# [choose] no ball -> centroid=(np.float64(1827.2), np.float64(1009.7)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1824.4), np.float64(1009.7)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1821.7), np.float64(1009.9)), pick tid=10
# [0050] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(64x147) target=(2200.5,1064.4) zoom_tgt=3.50 smooth=(2301.2,1069.3) z=3.50
# [choose] no ball -> centroid=(np.float64(1819.5), np.float64(1010.2)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1817.7), np.float64(1010.1)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1815.8), np.float64(1010.0)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1813.8), np.float64(1009.7)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1811.6), np.float64(1009.3)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1809.5), np.float64(1008.9)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1807.3), np.float64(1008.6)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1754.0), np.float64(1003.5)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1751.4), np.float64(1003.4)), pick tid=10
# [choose] no ball -> centroid=(np.float64(1799.0), np.float64(1008.2)), pick tid=10
# [0060] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(72x133) target=(2105.7,1053.8) zoom_tgt=3.50 smooth=(2239.8,1065.4) z=3.50
# [choose] no ball -> centroid=(np.float64(1795.9), np.float64(1007.4)), pick tid=10
# [choose] ball present -> nearest player tid=3, ball=(2060.1,1036.7)
# [choose] ball present -> nearest player tid=3, ball=(2052.4,1037.0)
# [choose] ball present -> nearest player tid=3, ball=(2044.3,1037.2)
# [choose] ball present -> nearest player tid=3, ball=(2035.3,1038.0)
# [choose] ball present -> nearest player tid=3, ball=(2026.0,1043.0)
# [choose] ball present -> nearest player tid=3, ball=(2018.8,1047.6)
# [choose] ball present -> nearest player tid=3, ball=(2011.5,1056.2)
# [choose] ball present -> nearest player tid=3, ball=(2004.0,1067.7)
# [choose] no ball -> centroid=(np.float64(1765.3), np.float64(1010.1)), pick tid=10
# [0070] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=3 pb_size=(55x145) target=(2033.0,1051.8) zoom_tgt=3.50 smooth=(2157.6,1058.3) z=3.50
# [choose] no ball -> centroid=(np.float64(1763.3), np.float64(1010.4)), pick tid=10
# [choose] ball present -> nearest player tid=3, ball=(1989.0,1090.4)
# [choose] no ball -> centroid=(np.float64(1891.1), np.float64(1023.7)), pick tid=4
# [choose] no ball -> centroid=(np.float64(1889.4), np.float64(1023.4)), pick tid=4
# [choose] no ball -> centroid=(np.float64(2318.5), np.float64(1009.9)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2313.6), np.float64(1004.8)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2312.1), np.float64(1004.6)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2309.8), np.float64(1004.5)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2307.8), np.float64(1004.5)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2306.5), np.float64(1004.6)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2305.3), np.float64(1004.7)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2303.7), np.float64(1004.7)), pick tid=184
# [0770] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(55x129) target=(2984.3,959.9) zoom_tgt=3.50 smooth=(2951.0,962.3) z=3.50
# [choose] no ball -> centroid=(np.float64(2302.4), np.float64(1004.6)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2300.6), np.float64(1004.1)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2298.3), np.float64(1003.4)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2296.1), np.float64(1003.0)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2294.1), np.float64(1002.6)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2291.8), np.float64(1002.8)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2289.9), np.float64(1003.1)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2288.4), np.float64(1003.5)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2287.1), np.float64(1003.9)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2285.8), np.float64(1004.0)), pick tid=184
# [0780] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(106x119) target=(2989.2,971.2) zoom_tgt=3.50 smooth=(2968.9,962.2) z=3.50
# [choose] no ball -> centroid=(np.float64(2284.0), np.float64(1004.2)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2282.1), np.float64(1004.1)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2279.8), np.float64(1003.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2277.3), np.float64(1003.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2276.3), np.float64(1003.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2275.2), np.float64(1002.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2273.5), np.float64(1002.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2271.6), np.float64(1002.3)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2269.4), np.float64(1001.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2267.2), np.float64(1001.7)), pick tid=13
# [0790] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(49x133) target=(2994.0,963.3) zoom_tgt=3.50 smooth=(2980.3,966.1) z=3.50
# [choose] no ball -> centroid=(np.float64(2265.1), np.float64(1001.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2262.8), np.float64(1000.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2260.2), np.float64(1000.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2257.6), np.float64(1000.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2254.9), np.float64(1001.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2252.0), np.float64(1001.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2249.5), np.float64(1001.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2247.2), np.float64(1001.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2244.8), np.float64(1001.3)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2242.6), np.float64(1001.3)), pick tid=13
# [0800] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(63x128) target=(2981.9,957.3) zoom_tgt=3.50 smooth=(2986.3,962.0) z=3.50
# [choose] no ball -> centroid=(np.float64(2240.5), np.float64(1001.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2238.3), np.float64(1001.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2236.1), np.float64(1001.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2233.7), np.float64(1001.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2230.9), np.float64(1001.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2227.9), np.float64(1001.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2225.5), np.float64(1001.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2223.3), np.float64(1001.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2221.0), np.float64(1001.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2218.6), np.float64(1001.1)), pick tid=13
# [0810] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(86x99) target=(2950.5,971.4) zoom_tgt=3.50 smooth=(2980.4,962.0) z=3.50
# [choose] no ball -> centroid=(np.float64(2216.0), np.float64(1001.2)), pick tid=13
# [choose] ball present -> nearest player tid=280, ball=(2974.9,946.4)
# [choose] ball present -> nearest player tid=280, ball=(2973.6,947.1)
# [choose] no ball -> centroid=(np.float64(2208.8), np.float64(1002.3)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2206.0), np.float64(1002.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2203.1), np.float64(1002.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2200.1), np.float64(1002.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2198.0), np.float64(1001.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2121.3), np.float64(1003.8)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2119.8), np.float64(1003.4)), pick tid=184
# [0820] uniq_cls=[0 1 3] players=10 balls=0 chosen_id=280 pb_size=(72x115) target=(2947.2,965.0) zoom_tgt=3.50 smooth=(2966.8,967.2) z=3.50
# [choose] no ball -> centroid=(np.float64(2192.9), np.float64(999.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2190.7), np.float64(999.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2188.8), np.float64(999.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2186.9), np.float64(998.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2184.6), np.float64(998.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2182.9), np.float64(998.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2180.4), np.float64(997.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2178.2), np.float64(996.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2176.3), np.float64(996.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2174.3), np.float64(996.4)), pick tid=13
# [0830] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(72x96) target=(2946.7,973.8) zoom_tgt=3.50 smooth=(2956.1,969.6) z=3.50
# [choose] no ball -> centroid=(np.float64(2095.3), np.float64(998.1)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2093.2), np.float64(997.5)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2091.1), np.float64(996.9)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2089.5), np.float64(996.4)), pick tid=184
# [choose] no ball -> centroid=(np.float64(2166.2), np.float64(994.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2164.9), np.float64(994.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2163.1), np.float64(993.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2161.2), np.float64(993.3)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2159.8), np.float64(992.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2213.7), np.float64(999.4)), pick tid=13
# [0840] uniq_cls=[0 1 3] players=10 balls=0 chosen_id=280 pb_size=(70x83) target=(2946.0,980.6) zoom_tgt=3.50 smooth=(2950.1,972.6) z=3.50
# [choose] no ball -> centroid=(np.float64(2130.4), np.float64(1001.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2155.6), np.float64(991.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2154.5), np.float64(990.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2153.3), np.float64(990.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2152.2), np.float64(990.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2151.2), np.float64(991.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2150.5), np.float64(990.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2149.5), np.float64(990.3)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2148.3), np.float64(990.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2146.2), np.float64(989.7)), pick tid=13
# [0850] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(69x84) target=(2946.8,980.5) zoom_tgt=3.50 smooth=(2947.8,976.4) z=3.50
# [choose] no ball -> centroid=(np.float64(2144.6), np.float64(989.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2142.9), np.float64(988.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2060.6), np.float64(988.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2139.7), np.float64(987.3)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2138.4), np.float64(987.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2137.7), np.float64(986.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2136.4), np.float64(986.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2135.0), np.float64(986.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2185.0), np.float64(994.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2132.5), np.float64(985.8)), pick tid=13
# [0860] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(65x114) target=(2939.9,966.1) zoom_tgt=3.50 smooth=(2946.8,976.6) z=3.50
# [choose] no ball -> centroid=(np.float64(2131.5), np.float64(985.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2131.2), np.float64(985.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2130.0), np.float64(984.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2128.6), np.float64(984.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2127.4), np.float64(983.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2126.3), np.float64(982.3)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2125.0), np.float64(981.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2200.6), np.float64(988.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2123.1), np.float64(982.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2122.4), np.float64(982.3)), pick tid=13
# [0870] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(60x116) target=(2931.7,963.5) zoom_tgt=3.50 smooth=(2942.8,971.5) z=3.50
# [choose] no ball -> centroid=(np.float64(2121.5), np.float64(982.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2196.7), np.float64(987.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2119.8), np.float64(982.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2119.1), np.float64(981.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2118.1), np.float64(981.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2116.8), np.float64(981.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2116.0), np.float64(981.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2115.1), np.float64(980.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2114.4), np.float64(980.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2113.4), np.float64(980.3)), pick tid=13
# [0880] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(60x114) target=(2925.0,965.9) zoom_tgt=3.50 smooth=(2936.2,967.5) z=3.50
# [choose] no ball -> centroid=(np.float64(2112.1), np.float64(980.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2110.8), np.float64(979.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2109.5), np.float64(978.6)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2108.0), np.float64(978.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2106.9), np.float64(978.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2106.1), np.float64(978.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2046.7), np.float64(975.8)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2045.4), np.float64(975.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2044.6), np.float64(975.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2104.0), np.float64(978.8)), pick tid=13
# [0890] uniq_cls=[0 1 3] players=11 balls=0 chosen_id=280 pb_size=(58x122) target=(2896.3,966.4) zoom_tgt=3.50 smooth=(2925.1,966.0) z=3.50
# [choose] no ball -> centroid=(np.float64(2044.7), np.float64(974.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2044.6), np.float64(974.9)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2103.4), np.float64(978.5)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2103.0), np.float64(978.1)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2102.7), np.float64(978.0)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2102.2), np.float64(977.7)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2101.6), np.float64(977.4)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2100.8), np.float64(977.2)), pick tid=13
# [choose] no ball -> centroid=(np.float64(2099.9), np.float64(977.1)), pick tid=13
# Video ended or read failed.
# Done frames: 900
# Saved: F:\OneDrive\spike的文件夹\留学\Upenn\2025 8-12\CIS 5810\AutoCameraMan\results\demo_v1.mp4
